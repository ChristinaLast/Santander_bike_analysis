# %% [markdown]
# ## Using Santander Cycling data (Random forest) to predict bike occupancy for December.
# https://cycling.data.tfl.gov.uk/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point, Polygon, MultiPolygon

# %matplotlib inline

import json
from xml.etree import ElementTree as ET
import requests
from io import BytesIO
from io import StringIO

from zipfile import ZipFile
import urllib.request
from urllib.request import urlopen
import os
from pandas.io.json import json_normalize
import itertools
from itertools import chain, starmap

# %%
bike_data_2012_zip = urllib.request.urlopen("https://cycling.data.tfl.gov.uk/usage-stats/cyclehireusagestats-2012.zip")
bike_data_2013_zip = urllib.request.urlopen("https://cycling.data.tfl.gov.uk/usage-stats/cyclehireusagestats-2013.zip")
bike_data_2014_zip = urllib.request.urlopen("https://cycling.data.tfl.gov.uk/usage-stats/cyclehireusagestats-2014.zip")
bike_data_2015_zip = urllib.request.urlopen("https://cycling.data.tfl.gov.uk/usage-stats/2015TripDatazip.zip")
bike_data_2016_zip = urllib.request.urlopen("https://cycling.data.tfl.gov.uk/usage-stats/2016TripDataZip.zip")

# %%
# Define function to parse zipfiles to dataframe
def zipfile_to_df(url):    
    with ZipFile(BytesIO(url.read())) as zipfile:
        dfs = []
        for col_name in zipfile.namelist():
            with zipfile.open(col_name) as csv:
                df = pd.read_csv(csv, index_col=None, header=0)
                dfs.append(df)
    data = pd.concat(dfs, ignore_index=True)
    return data

# %%
#Applying read function to 2015 and 2016 bike data
bike_2012_df = zipfile_to_df(bike_data_2012_zip)
#bike_2013_df = zipfile_to_df(bike_data_2013_zip)
#bike_2014_df = zipfile_to_df(bike_data_2014_zip)
bike_2015_df = zipfile_to_df(bike_data_2015_zip)
bike_2016_df = zipfile_to_df(bike_data_2016_zip)
# Out:
# /Users/clast/test_bike/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3242: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /Users/clast/test_bike/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
#Cleaning incorrect results on 2012 dataframe
bike_2012_df = bike_2012_df[bike_2012_df['StartStation Id'] != 'Tabletop1']

# %%
#Concatenating all dataframes that can be read in cleanly
bike_data = pd.concat([bike_2012_df,bike_2015_df,bike_2016_df], ignore_index=True).drop(['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 9','EndStation Logical Terminal','StartStation Logical Terminal','endStationPriority_id'], axis=1)
# Out:
# /Users/clast/test_bike/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
bike_data.head()
# Out:
#    Bike Id  Duration          End Date  EndStation Id  \
# 0    893.0    1238.0  04/01/2012 00:20          169.0
# 1   5621.0     207.0  04/01/2012 00:05          319.0
# 2   4365.0     636.0  04/01/2012 00:12          343.0
# 3   2708.0     194.0  04/01/2012 00:08          379.0
# 4     17.0     875.0  04/01/2012 00:20          340.0
#
#                             EndStation Name  Rental Id        Start Date  \
# 0              Porchester Place: Paddington    9340768  04/01/2012 00:00
# 1                Baldwin Street: St. Luke's    9345966  04/01/2012 00:01
# 2  Gloucester Slips Car Park: Regent's Park    9349921  04/01/2012 00:01
# 3            Turquoise Island: Notting Hill    9341757  04/01/2012 00:04
# 4              Bank of England Museum: Bank    9344212  04/01/2012 00:05
#
#   StartStation Id                        StartStation Name
# 0             224                    Whiteley's: Bayswater
# 1               3     Christopher Street: Liverpool Street
# ...

# %%
def clean_bike_data(dataframe):
#    print("Original shape: ",dataframe.shape)
    dataframe.dropna(axis=0, subset=["StartStation Id", "EndStation Id", "Start Date", "End Date"], inplace=True)
#    print("Shape after dropping Na results: ",dataframe.shape)
    
    dataframe["EndStation Id"] = dataframe["EndStation Id"].astype(int)
    dataframe["StartStation Id"] = dataframe["StartStation Id"].astype(int)
    dataframe["End Date"] = pd.to_datetime(dataframe["End Date"],infer_datetime_format=True)
    dataframe["Start Date"] = pd.to_datetime(dataframe["Start Date"],infer_datetime_format=True)

    dataframe = dataframe[dataframe["StartStation Id"] != dataframe["EndStation Id"]]
    dataframe = dataframe.loc[:,('Start Date',
                           'StartStation Id',
                           'End Date',
                           'EndStation Id',
                           'Duration')]                 
#    print("Shape after removing trips which start and end at the same location", dataframe.shape)
    ## Extra drop for duplicates
    dataframe.drop_duplicates(inplace=True)
#    print("Shape after removing duplicates: ",dataframe.shape)

# %%
bike_data = clean_bike_data(bike_data)

# %%
bike_locations = "https://tfl.gov.uk/tfl/syndication/feeds/cycle-hire/livecyclehireupdates.xml"

# %%
#url containing the locations of all Santander bike stops
bike_locations = "https://tfl.gov.uk/tfl/syndication/feeds/cycle-hire/livecyclehireupdates.xml"

def get_location_from_xml(url):
    response = requests.get(url)
    root = ET.fromstring(response.content)
    
    col_list = []
    for i in range(0, len(root)):
        id_list = int(root[i][0].text)
        name_list = str(root[i][1].text)
        lat_list = float(root[i][3].text)
        lon_list = float(root[i][4].text)
        capacity_list = int(root[i][12].text)
        col_list.append([id_list,name_list,lat_list,lon_list,capacity_list])
    
    all_locs = pd.DataFrame(list(col_list), columns = ["name","id","lat","lon","capacity"])
#    all_locs.to_dataframe(url.split('/')[7].split('.')[0]+'.csv', header=True, index=None)
    print("Shape of cycle hire locations: ",all_locs.shape)
    
    return all_locs

bike_locations = get_location_from_xml(bike_locations)
# Out:
# Shape of cycle hire locations:  (786, 5)

# %%
bike_locations
# Out:
#      name                                    id        lat       lon  capacity
# 0       1            River Street , Clerkenwell  51.529163 -0.109971        19
# 1       2        Phillimore Gardens, Kensington  51.499607 -0.197574        37
# 2       3  Christopher Street, Liverpool Street  51.521284 -0.084606        32
# 3       4       St. Chad's Street, King's Cross  51.530059 -0.120974        23
# 4       5         Sedding Street, Sloane Square  51.493130 -0.156876        27
# ..    ...                                   ...        ...       ...       ...
# 781   834           Gas Holders, Battersea Park  51.477966 -0.147857        26
# 782   835            Farringdon Street, Holborn  51.516785 -0.104948        25
# 783   836                 York Way, Kings Cross  51.541596 -0.125441        24
# 784   838         Fore Street Avenue, Guildhall  51.518093 -0.091402        25
# 785   839            Sea Containers, South Bank  51.508033 -0.106824        30
#
# [786 rows x 5 columns]

# %%
#matching the start stations with their location
all_data = bike_data.merge(bike_locations, left_on=['StartStation Id'], right_on=['name']).drop(columns='id')
all_data.rename(columns={"name": "sname", 
                                    "lat": "slat",
                                    "lon": "slon",
                                    "capacity": "scap"
                                   })
#mathcing the end stations to their locations
all_data = bike_data.merge(bike_locations, left_on=['EndStation Id'], right_on=['name']).drop(columns='id')
all_data = bike_data.rename(columns={"name": "ename", 
                                    "lat": "elat",
                                    "lon": "elon",
                                    "capacity": "ecap"
                                   })

# %%
all_data.head()
# Out:
#    Bike Id  Duration          End Date  EndStation Id  \
# 0    893.0    1238.0  04/01/2012 00:20          169.0
# 1   5621.0     207.0  04/01/2012 00:05          319.0
# 2   4365.0     636.0  04/01/2012 00:12          343.0
# 3   2708.0     194.0  04/01/2012 00:08          379.0
# 4     17.0     875.0  04/01/2012 00:20          340.0
#
#                             EndStation Name  Rental Id        Start Date  \
# 0              Porchester Place: Paddington    9340768  04/01/2012 00:00
# 1                Baldwin Street: St. Luke's    9345966  04/01/2012 00:01
# 2  Gloucester Slips Car Park: Regent's Park    9349921  04/01/2012 00:01
# 3            Turquoise Island: Notting Hill    9341757  04/01/2012 00:04
# 4              Bank of England Museum: Bank    9344212  04/01/2012 00:05
#
#   StartStation Id                        StartStation Name
# 0             224                    Whiteley's: Bayswater
# 1               3     Christopher Street: Liverpool Street
# ...

# %%
#Loading in datasets
import folium
import networkx as nx

import sklearn
from sklearn.cluster import spectral_clustering

from scipy.cluster import hierarchy
from scipy.spatial import distance

# %%
list(all_data.columns)
# Out:
# ['Bike Id',
#  'Duration',
#  'End Date',
#  'EndStation Id',
#  'EndStation Name',
#  'Rental Id',
#  'Start Date',
#  'StartStation Id',
#  'StartStation Name']

# %%
# Generating edgelist from dataframe
od =(all_data.groupby(['StartStation Id', 'EndStation Id'])
         .count()
         .rename(columns={'Duration' : 'weight'})
         .assign(inv_weight= lambda x: 1.0/x['weight'] )
         .reset_index()[['StartStation Id', 'EndStation Id','weight','inv_weight']])

#creating a route network
network = nx.from_pandas_edgelist(od, source = 'StartStation Id', 
                                   target = 'EndStation Id', 
                                   edge_attr = 'inv_weight',
                                   create_using= nx.DiGraph())

# %%
# %timeit all_data["End Date"] = pd.to_datetime(all_data["End Date"],infer_datetime_format=True)
# Out:
# 4.51 s ± 540 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_data["Start Date"] = pd.to_datetime(all_data["Start Date"],infer_datetime_format=True)
# Out:
# 3.26 s ± 355 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
all_data
# Out:
#           Bike Id  Duration            End Date  EndStation Id  \
# 0           893.0    1238.0 2012-04-01 00:20:00          169.0
# 1          5621.0     207.0 2012-04-01 00:05:00          319.0
# 2          4365.0     636.0 2012-04-01 00:12:00          343.0
# 3          2708.0     194.0 2012-04-01 00:08:00          379.0
# 4            17.0     875.0 2012-04-01 00:20:00          340.0
# ...           ...       ...                 ...            ...
# 29267597   1708.0     240.0 2017-03-01 21:12:00          773.0
# 29267598   8930.0     300.0 2017-03-01 21:13:00          633.0
# 29267599   4956.0     360.0 2017-03-01 21:39:00          680.0
# 29267600   7005.0    7380.0 2017-03-01 23:36:00          229.0
# 29267601   1383.0    7320.0 2017-03-01 23:36:00          229.0
#
#                                    EndStation Name  Rental Id  \
# 0                     Porchester Place: Paddington    9340768
# 1                       Baldwin Street: St. Luke's    9345966
# ...

# %%
all_data['Bike Id'].value_counts()
# Out:
# 6621.0     3492
# 6531.0     3484
# 5681.0     3449
# 4571.0     3441
# 9129.0     3432
#            ...
# 14078.0       4
# 14674.0       4
# 14133.0       3
# 12135.0       1
# 2500.0        1
# Name: Bike Id, Length: 14299, dtype: int64

# %%
busybike = all_data[all_data['Bike Id']==6531]
busybike.sort_values(by='Start Date').tail()
# Out:
#           Bike Id  Duration            End Date  EndStation Id  \
# 29190490   6531.0     420.0 2016-12-30 16:38:00          617.0
# 29221652   6531.0     540.0 2016-12-30 23:57:00          597.0
# 29224897   6531.0    1560.0 2016-12-31 14:00:00          250.0
# 29246194   6531.0     540.0 2017-01-01 03:11:00          589.0
# 29264556   6531.0     960.0 2017-03-01 12:30:00          701.0
#
#                         EndStation Name  Rental Id          Start Date  \
# 29190490          Elysium Place, Fulham   61379970 2016-12-30 16:31:00
# 29221652       Fulham Park Road, Fulham   61383630 2016-12-30 23:48:00
# 29224897        Royal Avenue 1, Chelsea   61388162 2016-12-31 13:34:00
# 29246194  Drayton Gardens, West Chelsea   61398252 2017-01-01 03:02:00
# 29264556   Vicarage Crescent, Battersea   61423763 2017-03-01 12:14:00
#
#          StartStation Id                           StartStation Name
# 29190490             655                       Crabtree Lane, Fulham
# ...

# %%
#investigating 659
nogeo = all_data[all_data['Bike Id']==659]

# %%
nogeo
# Out:
#           Bike Id  Duration            End Date  EndStation Id  \
# 475695      659.0     515.0 2012-08-21 07:33:00          428.0
# 480195      659.0    1372.0 2012-08-21 09:15:00          407.0
# 481050      659.0     826.0 2012-08-21 09:53:00          392.0
# 494314      659.0     908.0 2012-08-21 16:44:00          274.0
# 496366      659.0     624.0 2012-08-21 17:03:00          560.0
# ...           ...       ...                 ...            ...
# 29243752    659.0    1080.0 2017-03-01 18:35:00           64.0
# 29244950    659.0    1500.0 2017-03-01 19:56:00          584.0
# 29245052    659.0     960.0 2017-03-01 09:13:00          210.0
# 29248089    659.0    7380.0 2017-01-01 02:18:00          367.0
# 29260264    659.0     840.0 2017-02-01 20:59:00           36.0
#
#                                EndStation Name  Rental Id          Start Date  \
# 475695       Exhibition Road, South Kensington   15381910 2012-08-21 07:25:00
# ...

# %%
## Generate list of unique routes
unq_locs = all_data.loc[:,('StartStation Id','EndStation Id')]
print(unq_locs.shape)
unq_locs.drop_duplicates(inplace=True)
print(unq_locs.shape)
# Out:
# (29267602, 2)
# (496733, 2)

# %%
# Finding jumps in the use of the most busy bike
busybikenext = (busybike.sort_values(by='Start Date')
                .assign(NextStationId = busybike
                        .sort_values(by='Start Date')['StartStation Id']
                        .shift(-1)
                        .fillna(0)
                        .astype(int))
               )
# Creating dataframe of all the trips that 
jumps = busybikenext[~(busybikenext['EndStation Id'] == busybikenext['NextStationId'])]

jump_count = (jumps.groupby(['EndStation Id','NextStationId'])
                           .count()
                           .rename(columns = {'Duration':'weight'})
                           .assign(inv_weight= lambda x: 1.0/x['weight'] )
                           .reset_index()[['EndStation Id',
                                           'NextStationId', 
                                           'weight', 
                                           'inv_weight']]
             )
jump_network = nx.from_pandas_edgelist(jump_count.query('NextStationId != 0'),
                               source ='EndStation Id',
                               target = 'NextStationId',
                               edge_attr = 'inv_weight',
                               create_using=nx.DiGraph())

# %%
#Getting all unique station information
stations = (all_data.loc[:,('StartStation Id', 'slon','slat','StartStation Name')]
            .drop_duplicates()
            .set_index('StartStation Id')
           )
#stationPositions = {}
#Getting location information for all unique stations
#for c in stations.index:
#    stationPositions[c]=(stations['slon'][c],stations['slat'][c])

# %%
list(stations.columns)
# Out:
# ['slon', 'slat', 'StartStation Name']

# %%
nx.draw(jump_network,with_labels = False, node_size = 20, style='dotted', edge_color='blue',arrows=True)

# %%
#Plot rebalancing (jump) network for all bikes
# This cell takes a while to run... warning!
all_jumps = pd.DataFrame()
for i in all_data['Bike Id'].unique():
    bike = all_data[all_data['Bike Id']==i] 
    nextbike = (bike.sort_values(by='Start Date')
                        .assign(NextStationId = bike.sort_values(by='Start Date')['StartStation Id'].shift(-1).fillna(0).astype(int)
                               )
                )
    jumps = nextbike[~(nextbike['EndStation Id'] == nextbike['NextStationId'])]
    jumps.head()
    all_jumps = all_jumps.append(jumps)

# %%
all_jumps.sort_values(by ='EndStation Id',ascending=False)
# Out:
#           Bike Id  Duration            End Date  EndStation Id  \
# 27445542   5829.0     780.0 2017-03-01 18:08:00            820
# 27445531  14207.0     300.0 2017-01-01 02:11:00            820
# 27445536   6145.0     720.0 2016-12-28 20:52:00            820
# 27445469   9723.0     360.0 2017-03-01 18:27:00            820
# 27445586   3169.0    4800.0 2017-02-01 14:03:00            820
# ...           ...       ...                 ...            ...
# 22647881   5712.0    1200.0 2015-08-08 18:06:00              1
# 22641392   7933.0     691.0 2012-07-26 18:16:44              1
# 22647570   3443.0     352.0 2012-04-01 11:59:00              1
# 22653309   7811.0     749.0 2012-09-05 18:02:42              1
# 22648425   7748.0     756.0 2012-07-20 17:08:51              1
#
#                      EndStation Name  Rental Id          Start Date  \
# 27445542     Victory place, Walworth   61430939 2017-03-01 17:55:00
# 27445531     Victory place, Walworth   61397939 2017-01-01 02:06:00
# ...

# %%
all_jump_count = (all_jumps.query('NextStationId != 0').groupby(['EndStation Id', 'NextStationId'])
                 .count()
                 .rename(columns = {'Duration': 'weight'})
                 .assign( inv_weight = lambda x: 1.0/x['weight'])
                 .reset_index()[['EndStation Id',
                               'NextStationId',
                               'weight',
                               'inv_weight']])

# %%
# Find most frequent jump routes
all_jump_count.sort_values(by='weight',ascending=False).head()
# Out:
#         EndStation Id  NextStationId  weight  inv_weight
# 45819              66            546    5790    0.000173
# 45374              66             67    4260    0.000235
# 387999            579            374    3706    0.000270
# 257930            374             66    3380    0.000296
# 258272            374            436    3097    0.000323

# %%
# Use networkx to analyze total jump network and top-10 jump routes

alljumpnetwork = nx.from_pandas_edgelist(all_jump_count,
                                       source= 'EndStation Id',
                                       target='NextStationId',
                                       edge_attr='inv_weight',
                                       create_using=nx.DiGraph())
topjumpnetwork = nx.from_pandas_edgelist(all_jump_count.sort_values(by='weight',ascending=False).head(10),
                                       source= 'EndStation Id',
                                       target='NextStationId',
                                       edge_attr='inv_weight',
                                       create_using=nx.DiGraph())

# %%
# We're plotting a lot of jump routes here -- may take a minute or two
plt.figure(figsize = (12,6))
plt.title('All Balancing Trips')
nx.draw(alljumpnetwork,node_size=15,style='dotted',edge_color='green',arrows=True)

# %%
plt.title('Top 10 Balancing Trips')
nx.draw(topjumpnetwork, with_labels=True,node_size=15,style='dotted',edge_color='green',arrows=True)

# %% [markdown]
# The graph of the top ten bike journeys reveals that popular destinations and journey start points are Holborn (node 66) and Waterloo Station (node 374). Trips from Holborn to Waterloo station feature in the top ten most popular journeys, taking an average of 12 minutes (Very similar to the travel time on google maps bike mode). Another popular Santander bike journey is from Holborn Circus to New Fetter Lane, Holborn, where the average journey time is 1038 seconds (17.3 minutes). From Holborn Circus another popular route is to Hatton Garden, Holborn.
#
# A popular route is Newgate Street, St. Paul's to King Edward Street, St Pauls, with an average duration of 14 minutes. These stations are very near one another, which could potentially indicate people making this joruney are not cycling to get to a destination, but to explore the city location. Alternatively, it could indicate wayfinding in this location is difficult.
#
# Other popular trips include Queen Street 2, Bank to Waterloo Station 1, Waterloo and Abbey Orchard Street, Westminsterto Waterloo Station 1, Waterloo.

# %%
# visualize with folium
map_bike = folium.Map(location=[51.5074, -0.1277],tiles='cartodbpositron', zoom_start=13)

for i in stations.iterrows():
    folium.CircleMarker(location=[i[1][1],i[1][0],],radius=1,fill_opacity=1).add_to(map_bike)

map_bike
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#measures of centrality
degree_cent = nx.centrality.degree_centrality(network)
between_cent = nx.centrality.betweenness_centrality(network,weight='inv_weight')
closeness_cent = nx.centrality.closeness_centrality(network,distance='inv_weight')

# %%
# This is “left” eigenvector centrality which corresponds to the in-edges
eigen_cent = nx.centrality.eigenvector_centrality(network,weight='inv_weight')
eigen_cent_numpy = nx.centrality.eigenvector_centrality_numpy(network,weight='inv_weight')

# %%
# This is “right” eigenvector centrality which corresponds to the out-edges
eigen_cent_out = nx.centrality.eigenvector_centrality(network.reverse(),weight='inv_weight')
eigen_cent_numpy_out = nx.centrality.eigenvector_centrality_numpy(network.reverse(),weight='inv_weight')

# %%
centralities = {'degree_centrality':degree_cent,
                'betweeness_centrality':between_cent,
                'closeness_centrality':closeness_cent,
                'eigenvector_centrality':eigen_cent,
                'eigenvector_out_centrality':eigen_cent_out}

# %%
for key, values in centralities.items():
    stations['{}'.format(key)] = stations['StartStation Id'].map(values)

# %%
stations.to_csv('centralities_citibike.csv')

# %%
# eight bins diverging and qualitative color palette
diverge_colors = ["#d53e4f",
                    "#f46d43",
                    "#fdae61",
                    "#fee08b",
                    "#e6f598",
                    "#abdda4",
                    "#66c2a5",
                    "#3288bd"]

qualitative_colors=['#7fc97f',
                    '#beaed4',
                    '#fdc086',
                    '#ffff99',
                    '#386cb0',
                    '#f0027f',
                    '#bf5b17',
                    '#666666',]

# %%
# in python three .values() returns a dict so need to convert to a list to run np.digitize
values = degree_cent.values()
bins = np.linspace(min(degree_cent.values()),max(degree_cent.values()), num=8)
binassign = np.digitize(list(values), bins)
binassign = binassign - 1

# %%
#re-seting the index for stations database to iterate through the bike station ids
stations = stations.set_index('StartStation Id')

# %%
#visualising network centrality for Santander bike stations 
for num, centralities in enumerate([degree_cent,between_cent,closeness_cent,eigen_cent]):
    values = centralities.values()
    bins = np.linspace(min(centralities.values()),max(centralities.values()), num=8)
    binassign = np.digitize(list(values), bins)
    binassign = binassign - 1
    bin_dict = dict(zip(centralities.keys(), binassign))
    map_bike = folium.Map(location=[51.5074, -0.1277],
                          tiles='cartodbdark_matter',
                          zoom_start=12,
                         )

    for i in stations.iterrows():
        station_id = i[0]
        folium.CircleMarker(location=[i[1][1],i[1][0]],
                            radius=1,fill_opacity=1,
                            color=diverge_colors[bin_dict[station_id]],
                            fill_color=diverge_colors[bin_dict[station_id]]).add_to(map_bike)
    map_bike.save('centralitymap_{}.html'.format(num))
